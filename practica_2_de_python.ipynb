# %% [markdown]
# <a href="https://colab.research.google.com/github/ozkar0005/Mi_primer_repositorio/blob/main/practica_2_de_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Universidad Tecmilenio
# ## Fundamentos y aplicaciones de inteligencia artificial
# ![image.png](data:image/png;base64,...)

# %%
#Hola mundo
print("hola mundo")
# Out:
# hola mundo
